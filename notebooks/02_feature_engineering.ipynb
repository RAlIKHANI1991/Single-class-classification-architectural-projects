# %%
pip install mlflow
# Out:
# ...
#   Using cached docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# ...
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/10.8 MB ? eta -:--:--
#    - -------------------------------------- 0.5/10.8 MB 989.2 kB/s eta 0:00:11
#    -- ------------------------------------- 0.8/10.8 MB 1.0 MB/s eta 0:00:10
#    --- ------------------------------------ 1.0/10.8 MB 1.1 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.3/10.8 MB 1.1 MB/s eta 0:00:09
#    ----- ---------------------------------- 1.6/10.8 MB 1.1 MB/s eta 0:00:09
#    ------ --------------------------------- 1.8/10.8 MB 1.2 MB/s eta 0:00:08
#    ------- -------------------------------- 2.1/10.8 MB 1.2 MB/s eta 0:00:08
#    -------- ------------------------------- 2.4/10.8 MB 1.2 MB/s eta 0:00:08
#    --------- ------------------------------ 2.6/10.8 MB 1.2 MB/s eta 0:00:07
# ...

# %%
import mlflow

# %%
mlflow --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 mlflow --version
#
# NameError: name 'version' is not defined

# %%
import uvicorn

# %%
uvicorn --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 uvicorn --version
#
# NameError: name 'version' is not defined
